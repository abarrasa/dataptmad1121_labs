# %% [markdown]
# # Before your start:
# - Read the README.md file
# - Comment as much as you can and use the resources (README.md file)
# - Happy learning!

# %%
# Import numpy and pandas
import pandas as pd
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import adfuller, kpss
from statsmodels.tsa.arima.model import ARIMA
import pmdarima as pm
from statsmodels.tools.eval_measures import rmse

# %% [markdown]
# # Challenge 1 - Loading and Evaluating The Data
#
# In this lab, we will look at a dataset of sensor data from a cellular phone. The phone was carried in the subject's pocket for a few minutes while they walked around.
#
# To load the data, run the code below.

# %%
# Run this code:

sensor = pd.read_csv('../sub_1.csv')
sensor.drop(columns=['Unnamed: 0'], inplace=True)

# %% [markdown]
# Examine the data using the `head` function.

# %%
# Your code here:
sensor
# Out:
#       attitude.roll  attitude.pitch  attitude.yaw  gravity.x  gravity.y  \
# 0          1.528132       -0.733896      0.696372   0.741895   0.669768
# 1          1.527992       -0.716987      0.677762   0.753099   0.657116
# 2          1.527765       -0.706999      0.670951   0.759611   0.649555
# 3          1.516768       -0.704678      0.675735   0.760709   0.647788
# 4          1.493941       -0.703918      0.672994   0.760062   0.647210
# ...             ...             ...           ...        ...        ...
# 1746       1.797120       -0.562324      2.445889   0.824443   0.533154
# 1747       1.814297       -0.569719      2.449655   0.817212   0.539396
# 1748       1.830821       -0.578367      2.447967   0.809207   0.546658
# 1749       1.849557       -0.586962      2.439458   0.800485   0.553834
# 1750       1.869375       -0.596783      2.433775   0.790551   0.561984
#
#       gravity.z  rotationRate.x  rotationRate.y  rotationRate.z  \
# ...

# %% [markdown]
# Check whether there is any missing data. If there is any missing data, remove the rows containing missing data.

# %%
# Your code here:
sensor.isnull().sum()
# Out:
# attitude.roll         0
# attitude.pitch        0
# attitude.yaw          0
# gravity.x             0
# gravity.y             0
# gravity.z             0
# rotationRate.x        0
# rotationRate.y        0
# rotationRate.z        0
# userAcceleration.x    0
# userAcceleration.y    0
# userAcceleration.z    0
# dtype: int64

# %% [markdown]
# How many rows and columns are in our data?

# %%
# Your code here:
#filas
len(sensor.axes[0])
print("Number of rows is {}".format(len(sensor.axes[0])))
#columnas
len(sensor.axes[1])
print("Number of columns is {}".format(len(sensor.axes[1])))
# Out:
# Number of rows is 1751
# Number of columns is 12

# %% [markdown]
# To perform time series analysis on the data, we must change the index from a range index to a time series index. In the cell below, create a time series index using the `pd.date_range` function. Create a time series index starting at 1/1/2018 00:00:00 and ending at 1/1/2018 00:29:10. The number of periods is equal to the number of rows in `sensor`. The frequency should be set to `infer`.

# %%
# Your code here:

time_series = pd.date_range(start = "1/1/2018 00:00:00", end="1/1/2018 00:29:10", periods=1751)
pd.infer_freq(time_series)
time_series
# Out:
# DatetimeIndex(['2018-01-01 00:00:00', '2018-01-01 00:00:01',
#                '2018-01-01 00:00:02', '2018-01-01 00:00:03',
#                '2018-01-01 00:00:04', '2018-01-01 00:00:05',
#                '2018-01-01 00:00:06', '2018-01-01 00:00:07',
#                '2018-01-01 00:00:08', '2018-01-01 00:00:09',
#                ...
#                '2018-01-01 00:29:01', '2018-01-01 00:29:02',
#                '2018-01-01 00:29:03', '2018-01-01 00:29:04',
#                '2018-01-01 00:29:05', '2018-01-01 00:29:06',
#                '2018-01-01 00:29:07', '2018-01-01 00:29:08',
#                '2018-01-01 00:29:09', '2018-01-01 00:29:10'],
#               dtype='datetime64[ns]', length=1751, freq=None)

# %% [markdown]
# Assign the time series index to the dataframe's index.

# %%
# Your code here:
sensor.set_index(time_series, inplace =True)
sensor
# Out:
#                      attitude.roll  attitude.pitch  attitude.yaw  gravity.x  \
# 2018-01-01 00:00:00       1.528132       -0.733896      0.696372   0.741895
# 2018-01-01 00:00:01       1.527992       -0.716987      0.677762   0.753099
# 2018-01-01 00:00:02       1.527765       -0.706999      0.670951   0.759611
# 2018-01-01 00:00:03       1.516768       -0.704678      0.675735   0.760709
# 2018-01-01 00:00:04       1.493941       -0.703918      0.672994   0.760062
# ...                            ...             ...           ...        ...
# 2018-01-01 00:29:06       1.797120       -0.562324      2.445889   0.824443
# 2018-01-01 00:29:07       1.814297       -0.569719      2.449655   0.817212
# 2018-01-01 00:29:08       1.830821       -0.578367      2.447967   0.809207
# 2018-01-01 00:29:09       1.849557       -0.586962      2.439458   0.800485
# 2018-01-01 00:29:10       1.869375       -0.596783      2.433775   0.790551
#
# ...

# %%
sensor_reset = sensor.reset_index()

# %% [markdown]
# Our next step is to decompose the time series and evaluate the patterns in the data. Load the `statsmodels.api` submodule and plot the decomposed plot of `userAcceleration.x`. Set `freq=60` in the `seasonal_decompose` function. Your graph should look like the one below.
#
# ![time series decomposition](../images/tsa_decompose.png)

# %%
# Your code here:
plt.rcParams['figure.figsize'] = (20,10)
decomposition = sm.tsa.seasonal_decompose(sensor_reset['userAcceleration.x'], period=60)
decomposition.plot()

# %% [markdown]
# Plot the decomposed time series of `rotationRate.x` also with a frequency of 60.

# %%
plt.rcParams['figure.figsize'] = (20,10)
decomposition = sm.tsa.seasonal_decompose(sensor_reset['rotationRate.x'], period=60)
decomposition.plot()

# %% [markdown]
# # Challenge 2 - Modelling the Data
#
# To model our data, we should look at a few assumptions. First, let's plot the `lag_plot` to detect any autocorrelation. Do this for `userAcceleration.x`

# %%
# Your code here:
pd.plotting.lag_plot(sensor_reset['userAcceleration.x'], lag=1)
# Out:
# <AxesSubplot:xlabel='y(t)', ylabel='y(t + 1)'>

# %% [markdown]
# Create a lag plot for `rotationRate.x`

# %%
# Your code here:

pd.plotting.lag_plot(sensor_reset['rotationRate.x'], lag=1)
# Out:
# <AxesSubplot:xlabel='y(t)', ylabel='y(t + 1)'>

# %% [markdown]
# What are your conclusions from both visualizations?

# %%
# Your conclusions here:
"""
in the first plot we can see that data is from -1,5 to around 2, and the second one from -4 to almost 4. 
So in the second one data is more dispersed. However, in both of them autocorrelation exists.
"""
# Out:
# '\nin the first plot we can see that data is from -1,5 to around 2, and the second one from -4 to almost 4. \nSo in the second one data is more dispersed. However, in both of them autocorrelation exists.\n'

# %% [markdown]
# The next step will be to test both variables for stationarity. Perform the Augmented Dickey Fuller test on both variables below.

# %%
# Your code here:
result=adfuller(sensor_reset['userAcceleration.x'], autolag="AIC")
print(f'ADF Statistic: {result[0]}')
print(f'p-value: {result[1]}')
# Out:
# ADF Statistic: -17.957994086169762
# p-value: 2.823439483037483e-30

# %%
result = adfuller(sensor_reset['rotationRate.x'], autolag="AIC")
print(f'ADF Statistic: {result[0]}')
print(f'p-value: {result[1]}')
# Out:
# ADF Statistic: -5.269860625086428
# p-value: 6.320230335911989e-06

# %% [markdown]
# What are your conclusions from this test?

# %%
# Your conclusions here:
"""
p-value is smaller than 0,05 in both cases, so we reject H0 in both of them. So both are stationary
"""
# Out:
# '\np-value is smaller than 0,05 in both cases, so we reject H0 in both of them. So both are stationary\n'

# %% [markdown]
# Finally, we'll create an ARMA model for `userAcceleration.x`. Load the `ARMA` function from `statsmodels`. The order of the model is (2, 1). Split the data to train and test. Use the last 10 observations as the test set and all other observations as the training set.

# %%
# Your code here:

training = pm.auto_arima(sensor_reset["userAcceleration.x"][0:len(sensor_reset['userAcceleration.x']-10)])
training.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ...
# Dep. Variable:                      y   No. Observations:                 1751
# Model:               SARIMAX(2, 0, 1)   Log Likelihood                 379.399
# Date:                Sat, 19 Mar 2022   AIC                           -748.798
# Time:                        18:32:19   BIC                           -721.458
# Sample:                             0   HQIC                          -738.692
#                                - 1751
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.0244      0.006      3.759      0.000       0.012       0.037
# ar.L1          0.9888      0.036     27.765      0.000       0.919       1.059
# ar.L2         -0.3788      0.032    -11.684      0.000      -0.442      -0.315
# ...

# %%
training.predict(n_periods = 10)
# Out:
# array([-0.03504699,  0.01435709,  0.05185799,  0.07022557,  0.07418283,
#         0.07113852,  0.06662938,  0.06332388,  0.06176338,  0.06147241])

# %% [markdown]
# To compare our predictions with the observed data, we can compute the RMSE (Root Mean Squared Error) from the submodule `statsmodels.tools.eval_measures`. You can read more about this function [here](https://www.statsmodels.org/dev/generated/statsmodels.tools.eval_measures.rmse.html). Compute the RMSE for the last 10 rows of the data by comparing the observed and predicted data for the `userAcceleration.x` column.

# %%
# Your code here:
rmse( sensor_reset['userAcceleration.x'].tail(10), training.predict(n_periods = 10), axis=0)
# Out:
# 0.2309970644127164

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('iris-data.csv')
df
# Out:
#      sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 0                5.1             3.5              1.4             0.2
# 1                4.9             3.0              1.4             0.2
# 2                4.7             3.2              1.3             0.2
# 3                4.6             3.1              1.5             0.2
# 4                5.0             3.6              1.4             0.2
# ..               ...             ...              ...             ...
# 145              6.7             3.0              5.2             2.3
# 146              6.3             2.5              5.0             2.3
# 147              6.5             3.0              5.2             2.0
# 148              6.2             3.4              5.4             2.3
# 149              5.9             3.0              5.1             1.8
#
#               class
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# ...

# %%
df['class'].unique()
# Out:
# array(['Iris-setosa', 'Iris-setossa', 'Iris-versicolor', 'versicolor',
#        'Iris-virginica'], dtype=object)

# %%
df['class'] = df['class'].replace('versicolor', 'Iris-versicolor')
df['class'] = df['class'].replace('Iris-setossa', 'Iris-setosa')
df
# Out:
#      sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 0                5.1             3.5              1.4             0.2
# 1                4.9             3.0              1.4             0.2
# 2                4.7             3.2              1.3             0.2
# 3                4.6             3.1              1.5             0.2
# 4                5.0             3.6              1.4             0.2
# ..               ...             ...              ...             ...
# 145              6.7             3.0              5.2             2.3
# 146              6.3             2.5              5.0             2.3
# 147              6.5             3.0              5.2             2.0
# 148              6.2             3.4              5.4             2.3
# 149              5.9             3.0              5.1             1.8
#
#               class
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# ...

# %%
df.isnull().sum()
def missing_percentage(df):
    percent_missing = df.isnull().sum() * 100 / len(df)
    missing_values_df = pd.DataFrame({'column_name': df.columns,'percent_missing': percent_missing})
    return missing_values_df
missing_percentage(df)
# Out:
#                      column_name  percent_missing
# sepal_length_cm  sepal_length_cm         0.000000
# sepal_width_cm    sepal_width_cm         0.000000
# petal_length_cm  petal_length_cm         0.000000
# petal_width_cm    petal_width_cm         3.333333
# class                      class         0.000000

# %% [markdown]
# # Imputation of missing values

# %%
df_input = df.copy()
df_input['petal_width_cm'] = df_input['petal_width_cm'].fillna(df_input['petal_width_cm'].value_counts().index[0])
missing_percentage(df_input)
# Out:
#                      column_name  percent_missing
# sepal_length_cm  sepal_length_cm              0.0
# sepal_width_cm    sepal_width_cm              0.0
# petal_length_cm  petal_length_cm              0.0
# petal_width_cm    petal_width_cm              0.0
# class                      class              0.0

# %%
df_input
# Out:
#      sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 0                5.1             3.5              1.4             0.2
# 1                4.9             3.0              1.4             0.2
# 2                4.7             3.2              1.3             0.2
# 3                4.6             3.1              1.5             0.2
# 4                5.0             3.6              1.4             0.2
# ..               ...             ...              ...             ...
# 145              6.7             3.0              5.2             2.3
# 146              6.3             2.5              5.0             2.3
# 147              6.5             3.0              5.2             2.0
# 148              6.2             3.4              5.4             2.3
# 149              5.9             3.0              5.1             1.8
#
#               class
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# ...

# %%
xpoints = df_input['class']
ypoints = df_input['petal_length_cm']

plt.bar(xpoints, ypoints)
plt.show()

# %%
xpoints = df_input['class']
ypoints = df_input['petal_width_cm']

plt.bar(xpoints, ypoints)
plt.show()

# %% [markdown]
# # Enconding data / one-hot-encoding

# %%
cat_cols = ['class']
df_enconded = df[cat_cols]
cat_list = []
for col in cat_cols:
    cat = df[col].unique()
    cat_num = len(cat)
    cat_dict = {"categorical_variable":col,
                "number_of_possible_values":cat_num,
                "values":cat}
    cat_list.append(cat_dict)
    
cat_df = pd.DataFrame(cat_list).sort_values(by="number_of_possible_values",
                                                ascending=False).reset_index(drop=True)
cat_df
# Out:
#   categorical_variable  number_of_possible_values  \
# 0                class                          3
#
#                                            values
# 0  [Iris-setosa, Iris-versicolor, Iris-virginica]

# %%
cat_cols = ['class']
df_one_hot_encoding = pd.get_dummies(df,columns=['class'])
df_one_hot_encoding
# Out:
#      sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 0                5.1             3.5              1.4             0.2
# 1                4.9             3.0              1.4             0.2
# 2                4.7             3.2              1.3             0.2
# 3                4.6             3.1              1.5             0.2
# 4                5.0             3.6              1.4             0.2
# ..               ...             ...              ...             ...
# 145              6.7             3.0              5.2             2.3
# 146              6.3             2.5              5.0             2.3
# 147              6.5             3.0              5.2             2.0
# 148              6.2             3.4              5.4             2.3
# 149              5.9             3.0              5.1             1.8
#
#      class_Iris-setosa  class_Iris-versicolor  class_Iris-virginica
# ...
